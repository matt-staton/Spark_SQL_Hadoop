# %% [markdown]
# Define your mapper or reducer using main() and other functions as you see fit.
# Note that the variable INPUT is used inside main(), and is associated with sys.stdin
# When you run this on AWS, main() will read from sys.stdin

# %%
#!/usr/bin/python

import sys
import re


INPUT = sys.stdin

#def main():
   # for line in INPUT:
    #    words = line.split()
     #   for word in words:

            
# --- get all lines from stdin ---
def main():
    for line in INPUT:
        try:
            mystr = re.search(r'(^.*)(X-To:).*', line)    #Cannot have spaces in RegEx!!!!!!!!!!!!!!!
            line1 = mystr.group(1)
        except:
            continue
     
        line2 = re.split(r'\t+', line1)   

        m_id = re.search(r'(^.*)(<.*>)(.*)', line2[0])    #Cannot have spaces in RegEx!!!!!!!!!!!!!!!
    
        line2[0] = m_id.group(2)
        #mylist.append(line)

        # Print the key value pairs
        print '%s\t%s' % (line2[2], line2[0])
        print '%s\t%s' % (line2[3], line2[0])   
        
                        
            
if __name__ == '__main__':
    main()

# %% [markdown]
# Having evaluated the above cell, we now override (replace)
# the definition of INPUT to be a local file.

# %%
INPUT = open("dataSet3a.txt", 'r')

# %% [markdown]
# Now run the main() function. It will read the file "fox.txt".
#
# The file "fox.txt" looks like this:
# the quick brown fox jumped over the lazy dog sir
# quick brown brown over over over sir sir sir sir
#
# As you change your Python code, you'll re-evaluate the cell containing your code.
# After doing this, you need to re-evaluate the cell defining INPUT to again
# override the assignment of INPUT to sys.stdin

# %%
main()
# Out:
# From: jane.tholt@enron.com	<23551738.1075857497351.JavaMail.evans@thyme>
# To: outlook.team@enron.com	<23551738.1075857497351.JavaMail.evans@thyme>
# From: jane.tholt@enron.com	<23426663.1075857497542.JavaMail.evans@thyme>
# To: elizabeth.hernandez@enron.com	<23426663.1075857497542.JavaMail.evans@thyme>
# From: jane.tholt@enron.com	<14443098.1075857499469.JavaMail.evans@thyme>
# To: msable@sdge.com	<14443098.1075857499469.JavaMail.evans@thyme>
# From: jane.tholt@enron.com	<12402604.1075857499490.JavaMail.evans@thyme>
# To: marlo.james@enron.com	<12402604.1075857499490.JavaMail.evans@thyme>
# From: jane.tholt@enron.com	<10450485.1075857499511.JavaMail.evans@thyme>
# To: marlo.james@enron.com	<10450485.1075857499511.JavaMail.evans@thyme>
# From: jane.tholt@enron.com	<17412004.1075857499532.JavaMail.evans@thyme>
# To: bafjjfjefmbfzef@cs.com	<17412004.1075857499532.JavaMail.evans@thyme>
# From: jane.tholt@enron.com	<15357507.1075857499554.JavaMail.evans@thyme>
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-1c1ebf6a0a58> in <module>()
# ----> 1 reducer()
#
# NameError: name 'reducer' is not defined
